# %% [markdown]
# # SALES PREDICTION   OASIS INFOBYTE

# %% [markdown]
# # DONE BY - SRIKANTA MAHARA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading of Dataset

# %%
dataset = pd.read_csv("C:\\Users\\A\\Downloads\\Advertising.csv")

# %%
dataset
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
dataset.head(10)
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# 5           6    8.7   48.9       75.0    7.2
# 6           7   57.5   32.8       23.5   11.8
# 7           8  120.2   19.6       11.6   13.2
# 8           9    8.6    2.1        1.0    4.8
# 9          10  199.8    2.6       21.2   10.6

# %%
dataset.tail(10)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 190         191   39.5   41.1        5.8   10.8
# 191         192   75.5   10.8        6.0    9.9
# 192         193   17.2    4.1       31.6    5.9
# 193         194  166.8   42.0        3.6   19.6
# 194         195  149.7   35.6        6.0   17.3
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %% [markdown]
# # Checking Datatypes

# %%
dataset.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# Radio         float64
# Newspaper     float64
# Sales         float64
# dtype: object

# %% [markdown]
# # Checking Number of Rows and Coloumns

# %%
dataset.shape
# Out:
# (200, 5)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %% [markdown]
# # Descriptive Statistics

# %%
dataset.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
dataset.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
dff = dataset.drop(['Unnamed: 0'], axis=1)
dff.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %% [markdown]
# # Different PLots of Data

# %%
tv_sales = dataset["TV"]
plt.plot(tv_sales, label="TV Sales")
plt.title("TV Sales Data")
plt.xlabel("Month")
plt.ylabel("Sales (in units)")
plt.show()

# %%
sns.distplot(dataset['Radio'])
# Out:
# C:\Users\A\AppData\Local\Temp\ipykernel_5256\3438019946.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['Radio'])
# <Axes: xlabel='Radio', ylabel='Density'>

# %%
corr=dataset.corr()
corr
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(dataset.corr(), cmap="YlGnBu", annot= True)
plt.show()

# %%
sns.pairplot(dataset)

# %%
sns.jointplot(x = 'TV',y = 'Sales', data = dff, color='blue')

# %%
sns.jointplot(x = 'Radio',y = 'Sales', data = dff, color='black')

# %%
sns.boxplot(dataset['Newspaper'])
# Out:
# <Axes: >

# %%
X = dff.drop(columns='Sales')
#X is an indeoendent variable.

y = dff['Sales']
# is the target variable

# %%
X.describe()
# Out:
#                TV       Radio   Newspaper
# count  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000
# std     85.854236   14.846809   21.778621
# min      0.700000    0.000000    0.300000
# 25%     74.375000    9.975000   12.750000
# 50%    149.750000   22.900000   25.750000
# 75%    218.825000   36.525000   45.100000
# max    296.400000   49.600000  114.000000

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import zscore

X_Scaled = X.apply(zscore)
X_Scaled.describe().T
# Out:
#            count          mean       std       min       25%       50%  \
# TV         200.0  1.221245e-16  1.002509 -1.708823 -0.848530  0.031615
# Radio      200.0 -4.529710e-16  1.002509 -1.570868 -0.897321 -0.024579
# Newspaper  200.0  2.220446e-16  1.002509 -1.392646 -0.819550 -0.221137
#
#                 75%       max
# TV         0.838195  1.744029
# Radio      0.895430  1.778300
# Newspaper  0.669579  3.841171

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
X_train, X_test, y_train, y_test = train_test_split(X_Scaled,y,test_size = 0.3,random_state=10)

# %%
# Checking the Dimensions of Training and Testing Data
print("The Shape of X_train dataset:", X_train.shape)
print("The Shape of X_Test dataset:", X_test.shape)
print("The Shape of Y_Train dataset:", y_train.shape)
print("The Shape of Y_Test dataset:", y_test.shape)
# Out:
# The Shape of X_train dataset: (140, 3)
# The Shape of X_Test dataset: (60, 3)
# The Shape of Y_Train dataset: (140,)
# The Shape of Y_Test dataset: (60,)

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression(fit_intercept = True)

reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(f"Linear coefficients : {reg.coef_}")
print(f"Intercept : {reg.intercept_}")
# Out:
# Linear coefficients : [ 3.68520775  2.86599405 -0.08401343]
# Intercept : 14.122070736568478

# %%
preds = reg.predict(X_test)
from sklearn import metrics
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, preds)))
# Out:
# Root Mean Squared Error: 2.3182000750787872

# %%
from sklearn.metrics import r2_score
r2_score(y_test, preds)
# Out:
# 0.8567790678044408

# %%
from sklearn.preprocessing import StandardScaler
Sc=StandardScaler()
x_train_scaled=Sc.fit_transform(X_train)
x_test_scaled=Sc.fit_transform(X_test)

# %%
x_test_scaled
# Out:
# array([[ 0.62652274,  0.22130326, -0.95698961],
#        [-1.47873541,  1.49025399,  2.01344586],
#        [ 0.70677268,  0.10356557,  1.03686434],
#        [ 1.38629165,  1.03892615,  1.61557932],
#        [ 0.68592854,  1.0193032 ,  0.41293725],
#        [-0.0342365 , -0.14499179, -0.51391096],
#        [ 0.39411058, -0.52436881, -0.22003226],
#        [ 0.50354232,  1.5229589 ,  1.33526425],
#        [ 0.69009737,  1.16320483, -0.14769289],
#        [-1.39014782,  1.29402449,  1.75573685],
#        [ 1.44986628,  1.0585491 ,  0.9373977 ],
#        [-0.88050859, -1.32890974, -0.28332921],
#        [-1.39327444,  1.15012287,  2.66450022],
#        [ 0.72865903,  0.46331964,  0.33607667],
#        [ 0.82245766,  0.40445079,  1.97727618],
#        [-0.49906082,  0.22784425, -0.99768051],
#        [ 1.09238927,  0.0512377 , -1.12879562],
#        [-1.51312824,  0.24746719, -0.9524684 ],
#        [ 0.94960691,  0.77728683, -0.32854132],
#        [ 0.56711694,  1.24169663, -0.4913049 ],
#        [ 0.38785734, -0.32813932, -0.94794719],
#        [-1.56211197,  0.88194256, -0.98411688],
#        [ 1.15387949,  1.08471303,  1.09564008],
#        [-0.41568426,  0.94735239,  1.47994299],
#        [ 1.35085661, -1.04764746, -0.40992311],
#        [-1.3734725 , -0.28889342,  0.90122801],
#        [-1.30260243,  0.84269666, -0.95698961],
#        [-1.1056253 ,  0.86231961,  0.66160384],
#        [ 0.93084719,  1.00622124, -0.54103822],
#        [-1.36513485, -0.39354915, -0.60885638],
#        [-0.19682079, -0.50474586,  0.18687671],
#        [ 0.80682455,  0.75766388,  0.06932523],
#        [-1.28280049, -1.60363103, -0.44157159],
#        [-1.27133622, -1.61017201,  0.11453734],
#        [ 1.46028835, -1.44010645, -0.9931593 ],
#        [ 1.31437937, -1.55784415, -0.30593526],
#        [-0.7335574 , -1.70828676, -0.96151082],
#        [ 1.3935871 , -1.01494255, -1.08810473],
#        [-0.63454774, -1.06072943,  0.23661003],
#        [ 0.74846096, -1.48589333, -0.7851836 ],
#        [-1.15773565,  0.9800573 , -1.11523199],
#        [-0.3166746 , -0.42625407, -0.85300177],
#        [-0.08009361,  0.2082213 , -0.80778966],
#        [-1.12125841, -0.01417213, -0.45061401],
#        [ 0.62756495,  1.53604087,  0.32703425],
#        [-1.29009594,  0.45023767, -0.50486854],
#        [ 0.38889954, -0.58323766, -0.56816549],
#        [ 0.84955504, -1.14576221, -0.98411688],
#        [-1.49332631,  0.1297295 ,  0.49431904],
#        [-0.11865527, -0.77292617, -0.22003226],
#        [-0.92011246, -0.88412289, -0.55008064],
#        [ 0.58691888, -1.15884418, -0.18386257],
#        [ 1.51969415,  0.66609011,  3.18443945],
#        [ 0.13460103,  0.69879503, -1.04289262],
#        [ 0.90479201, -1.37469662, -0.31497768],
#        [-1.01182667, -1.5774671 , -0.40992311],
#        [ 1.31646378,  1.49025399,  0.51240389],
#        [ 0.50562673,  0.29325408,  0.37224635],
#        [-0.16972341, -1.38777859, -0.95698961],
#        [-0.87217093, -0.94299173,  0.28634335]])

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train_scaled,y_train)
y_pred=lr.predict(x_test_scaled)

# %%
y_pred
# Out:
# array([16.69529825, 12.67352766, 16.47929137, 21.40454627, 19.01573161,
#        13.33899899, 13.74403832, 19.71121629, 19.4787467 , 12.45501033,
#        21.73683187,  7.07268938, 11.96660015, 17.6182639 , 17.6431139 ,
#        12.80473922, 17.85399078,  9.33114593, 19.31825977, 19.29910315,
#        14.3308803 , 10.93508495, 20.76792848, 14.89699843, 15.6241719 ,
#         8.16443848, 11.72522584, 12.32974115, 19.909989  ,  8.02707071,
#        11.7109997 , 18.73403495,  4.92055987,  4.89579042, 14.95733267,
#        14.06417038,  6.58069806, 15.920536  ,  8.63304433, 12.33804019,
#        12.62546455, 11.6002584 , 14.19033418,  9.92080755, 20.26284892,
#        10.63520272, 13.59057264, 13.6556959 ,  8.95063759, 11.26779626,
#         8.19918632, 12.63961647, 20.69643217, 16.32590792, 13.15268948,
#         5.93280505, 22.51397382, 16.36520136,  9.43495983,  8.13172923])

# %%
from sklearn.metrics import mean_squared_error
import math
print(math.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# 2.6619456850457546

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred,c='g')
